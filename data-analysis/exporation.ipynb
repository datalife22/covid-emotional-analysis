# %%
import pandas as pd

# %%
df_it = pd.read_csv('data/data-it.csv')
df_us = pd.read_csv('data/data-us.csv')

# %%
df_it.describe()
# Out:
#        Con quante persone hai vissuto in quel periodo?   Quarantena  \
# count                                      1983.000000  2391.000000
# mean                                          3.084720     4.437474
# std                                           1.144849     0.865519
# min                                           1.000000     1.000000
# 25%                                           2.000000     4.000000
# 50%                                           3.000000     5.000000
# 75%                                           4.000000     5.000000
# max                                          10.000000     5.000000
#
#           Lockdown  Chiusura Scuole & Università   Green Pass  \
# count  2391.000000                   2391.000000  2391.000000
# mean      3.967378                      3.760351     4.061899
# std       1.147210                      1.234050     1.221639
# min       1.000000                      1.000000     1.000000
# ...
